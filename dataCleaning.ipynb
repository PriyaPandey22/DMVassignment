# %%
import pandas as pd

# %%
DataSet1=pd.read_csv("1_jan_ONTIME_REPORTING.csv")
DataSet2=pd.read_csv("2_Feb_ONTIME_REPORTING.csv")
DataSet3=pd.read_csv("3_march_ONTIME_REPORTING.csv")
DataSet4=pd.read_csv("4_April_ONTIME_REPORTING.csv")
DataSet5=pd.read_csv("5_may_ONTIME_REPORTING.csv")
DataSet6=pd.read_csv("6_June_ONTIME_REPORTING.csv")
DataSet7=pd.read_csv("7_july_ONTIME_REPORTING.csv")
DataSet8=pd.read_csv("8_Aug_ONTIME_REPORTING.csv")
DataSet9=pd.read_csv("9_Sept_ONTIME_REPORTING.csv")
DataSet10=pd.read_csv("10_Oct_ONTIME_REPORTING.csv")
DataSet11=pd.read_csv("11_Nov_ONTIME_REPORTING.csv")
DataSet12=pd.read_csv("12_Dec_ONTIME_REPORTING.csv")
# Out:
# C:\Users\PRIYA PANDEY\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (36) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\PRIYA PANDEY\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (35,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
DataSet1.head
# Out:
# <bound method NDFrame.head of         MONTH     FL_DATE  OP_CARRIER_FL_NUM ORIGIN ORIGIN_CITY_NAME  \
# 0           1  2020-01-01               5888    ONT      Ontario, CA
# 1           1  2020-01-01               6276    ONT      Ontario, CA
# 2           1  2020-01-01               4598    ONT      Ontario, CA
# 3           1  2020-01-01               4761    ONT      Ontario, CA
# 4           1  2020-01-01               5162    ONT      Ontario, CA
# ...       ...         ...                ...    ...              ...
# 607341      1  2020-01-18               4960    ATL      Atlanta, GA
# 607342      1  2020-01-19               4960    ATL      Atlanta, GA
# 607343      1  2020-01-20               4960    ATL      Atlanta, GA
# 607344      1  2020-01-21               4960    ATL      Atlanta, GA
# 607345      1  2020-01-22               4960    ATL      Atlanta, GA
#
#        ORIGIN_STATE_NM DEST     DEST_CITY_NAME DEST_STATE_NM  CRS_DEP_TIME  \
# ...

# %%
DataSet1.isnull().sum()
# Out:
# MONTH                           0
# FL_DATE                         0
# OP_CARRIER_FL_NUM               0
# ORIGIN                          0
# ORIGIN_CITY_NAME                0
# ORIGIN_STATE_NM                 0
# DEST                            0
# DEST_CITY_NAME                  0
# DEST_STATE_NM                   0
# CRS_DEP_TIME                    0
# DEP_TIME                     6664
# DEP_DELAY                    6699
# TAXI_OUT                     6822
# WHEELS_OFF                   6822
# WHEELS_ON                    7075
# TAXI_IN                      7075
# CRS_ARR_TIME                    0
# ARR_TIME                     7075
# ARR_DELAY                    8078
# CANCELLED                       0
# DIVERTED                        0
# CRS_ELAPSED_TIME                0
# ACTUAL_ELAPSED_TIME          8078
# AIR_TIME                     8078
# FLIGHTS                         0
# DISTANCE                        0
# CARRIER_DELAY              525061
# ...

# %%
DataSetAfterDrop1=DataSet1.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop1.describe
# Out:
# <bound method NDFrame.describe of            FL_DATE  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME ORIGIN_STATE_NM  \
# 0       2020-01-01               5888      Ontario, CA      California
# 1       2020-01-01               6276      Ontario, CA      California
# 2       2020-01-01               4598      Ontario, CA      California
# 3       2020-01-01               4761      Ontario, CA      California
# 4       2020-01-01               5162      Ontario, CA      California
# ...            ...                ...              ...             ...
# 607341  2020-01-18               4960      Atlanta, GA         Georgia
# 607342  2020-01-19               4960      Atlanta, GA         Georgia
# 607343  2020-01-20               4960      Atlanta, GA         Georgia
# 607344  2020-01-21               4960      Atlanta, GA         Georgia
# 607345  2020-01-22               4960      Atlanta, GA         Georgia
#
#            DEST_CITY_NAME DEST_STATE_NM  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  \
# ...

# %%
DataSetAfterDrop2=DataSet2.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop3=DataSet3.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop4=DataSet4.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop5=DataSet5.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop6=DataSet6.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop7=DataSet7.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop8=DataSet8.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop9=DataSet9.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop10=DataSet10.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop11=DataSet11.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop12=DataSet12.drop(['MONTH','ORIGIN','DEST','TAXI_OUT','WHEELS_OFF','WHEELS_ON','TAXI_IN','AIR_TIME','FLIGHTS','DIV_REACHED_DEST','DIV_ACTUAL_ELAPSED_TIME','DIV_ARR_DELAY','DIV_DISTANCE','DIV1_AIRPORT','DIV2_AIRPORT','DIV3_AIRPORT','DIV4_AIRPORT','DIV5_AIRPORT','Unnamed: 40'], axis = 1)

# %%
DataSetAfterDrop10.head
# Out:
# <bound method NDFrame.head of            FL_DATE  OP_CARRIER_FL_NUM       ORIGIN_CITY_NAME ORIGIN_STATE_NM  \
# 0       2020-10-08               2259  Dallas/Fort Worth, TX           Texas
# 1       2020-10-09               2259  Dallas/Fort Worth, TX           Texas
# 2       2020-10-11               2259  Dallas/Fort Worth, TX           Texas
# 3       2020-10-12               2259  Dallas/Fort Worth, TX           Texas
# 4       2020-10-13               2259  Dallas/Fort Worth, TX           Texas
# ...            ...                ...                    ...             ...
# 352101  2020-10-05                468          Santa Ana, CA      California
# 352102  2020-10-05                467             Newark, NJ      New Jersey
# 352103  2020-10-05                465             Denver, CO        Colorado
# 352104  2020-10-05                464             Denver, CO        Colorado
# 352105  2020-10-05                462             Denver, CO        Colorado
#
# ...

# %%
df1 = DataSetAfterDrop1.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df1.isnull().sum()
# Out:
# FL_DATE                     0
# OP_CARRIER_FL_NUM           0
# ORIGIN_CITY_NAME            0
# ORIGIN_STATE_NM             0
# DEST_CITY_NAME              0
# DEST_STATE_NM               0
# CRS_DEP_TIME                0
# DEP_TIME                    0
# DEP_DELAY                   0
# CRS_ARR_TIME                0
# ARR_TIME                    0
# ARR_DELAY                   0
# CANCELLED                   0
# DIVERTED                    0
# CRS_ELAPSED_TIME            0
# ACTUAL_ELAPSED_TIME         0
# DISTANCE                    0
# CARRIER_DELAY          516983
# WEATHER_DELAY          516983
# NAS_DELAY              516983
# SECURITY_DELAY         516983
# LATE_AIRCRAFT_DELAY    516983
# dtype: int64

# %%
df2 = DataSetAfterDrop2.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df3 = DataSetAfterDrop3.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df4 = DataSetAfterDrop4.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df5 = DataSetAfterDrop5.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df6 = DataSetAfterDrop6.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df7 = DataSetAfterDrop7.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df8 = DataSetAfterDrop8.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df9 = DataSetAfterDrop9.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df10 = DataSetAfterDrop10.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])

# %%
df11 = DataSetAfterDrop11.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df12 = DataSetAfterDrop12.dropna(subset=['DEP_TIME', 'DEP_DELAY','ARR_TIME','ARR_DELAY'])
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df1['CARRIER_DELAY'] = df1['CARRIER_DELAY'].fillna(0)
df1['WEATHER_DELAY'] = df1['WEATHER_DELAY'].fillna(0)
df1['NAS_DELAY'] = df1['NAS_DELAY'].fillna(0)
df1['SECURITY_DELAY'] = df1['SECURITY_DELAY'].fillna(0)
df1['LATE_AIRCRAFT_DELAY'] = df1['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# <ipython-input-36-ca9dc2644ea1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['CARRIER_DELAY'] = df1['CARRIER_DELAY'].fillna(0)
# <ipython-input-36-ca9dc2644ea1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['WEATHER_DELAY'] = df1['WEATHER_DELAY'].fillna(0)
# <ipython-input-36-ca9dc2644ea1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1.isnull().sum()
# Out:
# FL_DATE                0
# OP_CARRIER_FL_NUM      0
# ORIGIN_CITY_NAME       0
# ORIGIN_STATE_NM        0
# DEST_CITY_NAME         0
# DEST_STATE_NM          0
# CRS_DEP_TIME           0
# DEP_TIME               0
# DEP_DELAY              0
# CRS_ARR_TIME           0
# ARR_TIME               0
# ARR_DELAY              0
# CANCELLED              0
# DIVERTED               0
# CRS_ELAPSED_TIME       0
# ACTUAL_ELAPSED_TIME    0
# DISTANCE               0
# CARRIER_DELAY          0
# WEATHER_DELAY          0
# NAS_DELAY              0
# SECURITY_DELAY         0
# LATE_AIRCRAFT_DELAY    0
# dtype: int64

# %%
df2['CARRIER_DELAY'] = df2['CARRIER_DELAY'].fillna(0)
df2['WEATHER_DELAY'] = df2['WEATHER_DELAY'].fillna(0)
df2['NAS_DELAY'] = df2['NAS_DELAY'].fillna(0)
df2['SECURITY_DELAY'] = df2['SECURITY_DELAY'].fillna(0)
df2['LATE_AIRCRAFT_DELAY'] = df2['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# <ipython-input-38-2dd9135d71ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['CARRIER_DELAY'] = df2['CARRIER_DELAY'].fillna(0)
# <ipython-input-38-2dd9135d71ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['WEATHER_DELAY'] = df2['WEATHER_DELAY'].fillna(0)
# <ipython-input-38-2dd9135d71ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df3['CARRIER_DELAY'] = df3['CARRIER_DELAY'].fillna(0)
df3['WEATHER_DELAY'] = df3['WEATHER_DELAY'].fillna(0)
df3['NAS_DELAY'] = df3['NAS_DELAY'].fillna(0)
df3['SECURITY_DELAY'] = df3['SECURITY_DELAY'].fillna(0)
df3['LATE_AIRCRAFT_DELAY'] = df3['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# <ipython-input-39-0a24fd39f1eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['CARRIER_DELAY'] = df3['CARRIER_DELAY'].fillna(0)
# <ipython-input-39-0a24fd39f1eb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['WEATHER_DELAY'] = df3['WEATHER_DELAY'].fillna(0)
# <ipython-input-39-0a24fd39f1eb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df4['CARRIER_DELAY'] = df4['CARRIER_DELAY'].fillna(0)
df4['WEATHER_DELAY'] = df4['WEATHER_DELAY'].fillna(0)
df4['NAS_DELAY'] = df4['NAS_DELAY'].fillna(0)
df4['SECURITY_DELAY'] = df4['SECURITY_DELAY'].fillna(0)
df4['LATE_AIRCRAFT_DELAY'] = df4['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# <ipython-input-40-8ab91ceea97b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['CARRIER_DELAY'] = df4['CARRIER_DELAY'].fillna(0)
# <ipython-input-40-8ab91ceea97b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['WEATHER_DELAY'] = df4['WEATHER_DELAY'].fillna(0)
# <ipython-input-40-8ab91ceea97b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df5['CARRIER_DELAY'] = df5['CARRIER_DELAY'].fillna(0)
df5['WEATHER_DELAY'] = df5['WEATHER_DELAY'].fillna(0)
df5['NAS_DELAY'] = df5['NAS_DELAY'].fillna(0)
df5['SECURITY_DELAY'] = df5['SECURITY_DELAY'].fillna(0)
df5['LATE_AIRCRAFT_DELAY'] = df5['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# <ipython-input-41-e53c090d491e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['CARRIER_DELAY'] = df5['CARRIER_DELAY'].fillna(0)
# <ipython-input-41-e53c090d491e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['WEATHER_DELAY'] = df5['WEATHER_DELAY'].fillna(0)
# <ipython-input-41-e53c090d491e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df6['CARRIER_DELAY'] = df6['CARRIER_DELAY'].fillna(0)
df6['WEATHER_DELAY'] = df6['WEATHER_DELAY'].fillna(0)
df6['NAS_DELAY'] = df6['NAS_DELAY'].fillna(0)
df6['SECURITY_DELAY'] = df6['SECURITY_DELAY'].fillna(0)
df6['LATE_AIRCRAFT_DELAY'] = df6['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df7['CARRIER_DELAY'] = df7['CARRIER_DELAY'].fillna(0)
df7['WEATHER_DELAY'] = df7['WEATHER_DELAY'].fillna(0)
df7['NAS_DELAY'] = df7['NAS_DELAY'].fillna(0)
df7['SECURITY_DELAY'] = df7['SECURITY_DELAY'].fillna(0)
df7['LATE_AIRCRAFT_DELAY'] = df7['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df8['CARRIER_DELAY'] = df8['CARRIER_DELAY'].fillna(0)
df8['WEATHER_DELAY'] = df8['WEATHER_DELAY'].fillna(0)
df8['NAS_DELAY'] = df8['NAS_DELAY'].fillna(0)
df8['SECURITY_DELAY'] = df8['SECURITY_DELAY'].fillna(0)
df8['LATE_AIRCRAFT_DELAY'] = df8['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df9['CARRIER_DELAY'] = df9['CARRIER_DELAY'].fillna(0)
df9['WEATHER_DELAY'] = df9['WEATHER_DELAY'].fillna(0)
df9['NAS_DELAY'] = df9['NAS_DELAY'].fillna(0)
df9['SECURITY_DELAY'] = df9['SECURITY_DELAY'].fillna(0)
df9['LATE_AIRCRAFT_DELAY'] = df9['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df10['CARRIER_DELAY'] = df10['CARRIER_DELAY'].fillna(0)
df10['WEATHER_DELAY'] = df10['WEATHER_DELAY'].fillna(0)
df10['NAS_DELAY'] = df10['NAS_DELAY'].fillna(0)
df10['SECURITY_DELAY'] = df10['SECURITY_DELAY'].fillna(0)
df10['LATE_AIRCRAFT_DELAY'] = df10['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df11['CARRIER_DELAY'] = df11['CARRIER_DELAY'].fillna(0)
df11['WEATHER_DELAY'] = df11['WEATHER_DELAY'].fillna(0)
df11['NAS_DELAY'] = df11['NAS_DELAY'].fillna(0)
df11['SECURITY_DELAY'] = df11['SECURITY_DELAY'].fillna(0)
df11['LATE_AIRCRAFT_DELAY'] = df11['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df12['CARRIER_DELAY'] = df12['CARRIER_DELAY'].fillna(0)
df12['WEATHER_DELAY'] = df12['WEATHER_DELAY'].fillna(0)
df12['NAS_DELAY'] = df12['NAS_DELAY'].fillna(0)
df12['SECURITY_DELAY'] = df12['SECURITY_DELAY'].fillna(0)
df12['LATE_AIRCRAFT_DELAY'] = df12['LATE_AIRCRAFT_DELAY'].fillna(0)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df2.isnull().sum()
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df1.to_csv("JanuaryData.csv")
df2.to_csv("FebruaryData.csv")
df3.to_csv("MarchData.csv")
df4.to_csv("AprilData.csv")
df5.to_csv("MayData.csv")
df6.to_csv("JuneData.csv")
df7.to_csv("JulyData.csv")
df8.to_csv("AugustData.csv")
df9.to_csv("SeptemberData.csv")
df10.to_csv("OctoberData.csv")
df11.to_csv("NovemberData.csv")
df12.to_csv("DecemberData.csv")
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df1.to_excel("JanuaryData.xlsx")
df2.to_excel("FebruaryData.xlsx")
df3.to_excel("MarchData.xlsx")
df4.to_excel("AprilData.xlsx")
df5.to_excel("MayData.xlsx")
df6.to_excel("JuneData.xlsx")
df7.to_excel("JulyData.xlsx")
df8.to_excel("AugustData.xlsx")
df9.to_excel("SeptemberData.xlsx")
df10.to_excel("OctoberData.xlsx")
df11.to_excel("NovemberData.xlsx")
df12.to_excel("DecemberData.xlsx")
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\PRIYA PANDEY\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...
